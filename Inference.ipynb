# %% [markdown]
# # RESTBERTa Application
# This notebook demonstrates the application of a RESTBERTa model.
# It relies on the same processing pipelines used by the Flask application (see [tools](https://github.com/SebastianKotstein/RESTBERTa/tree/master/tools)).

# %% [markdown]
# ## Install Dependencies

# %%
# !pip install tensorflow==2.13.0
# !pip install transformers==4.33.2
# !pip install numpy==1.24.3
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: tensorflow==2.13.0 in /Users/sebastiankotstein/anaconda3/envs/tf/lib/python3.9/site-packages (2.13.0)
# Requirement already satisfied: tensorflow-macos==2.13.0 in /Users/sebastiankotstein/anaconda3/envs/tf/lib/python3.9/site-packages (from tensorflow==2.13.0) (2.13.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/sebastiankotstein/anaconda3/envs/tf/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow==2.13.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/sebastiankotstein/anaconda3/envs/tf/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow==2.13.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.1.21 in /Users/sebastiankotstein/anaconda3/envs/tf/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow==2.13.0) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /Users/sebastiankotstein/anaconda3/envs/tf/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow==2.13.0) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/sebastiankotstein/anaconda3/envs/tf/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow==2.13.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /Users/sebastiankotstein/anaconda3/envs/tf/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow==2.13.0) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/sebastiankotstein/anaconda3/envs/tf/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow==2.13.0) (16.0.6)
# Requirement already satisfied: numpy<=1.24.3,>=1.22 in /Users/sebastiankotstein/anaconda3/envs/tf/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow==2.13.0) (1.24.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/sebastiankotstein/anaconda3/envs/tf/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow==2.13.0) (3.3.0)
# Requirement already satisfied: packaging in /Users/sebastiankotstein/anaconda3/envs/tf/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow==2.13.0) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /Users/sebastiankotstein/anaconda3/envs/tf/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow==2.13.0) (4.24.3)
# Requirement already satisfied: setuptools in /Users/sebastiankotstein/anaconda3/envs/tf/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow==2.13.0) (68.2.2)
# Requirement already satisfied: six>=1.12.0 in /Users/sebastiankotstein/anaconda3/envs/tf/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow==2.13.0) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/sebastiankotstein/anaconda3/envs/tf/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow==2.13.0) (2.3.0)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.6.6 in /Users/sebastiankotstein/anaconda3/envs/tf/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow==2.13.0) (4.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/sebastiankotstein/anaconda3/envs/tf/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow==2.13.0) (1.15.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/sebastiankotstein/anaconda3/envs/tf/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow==2.13.0) (1.58.0)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in /Users/sebastiankotstein/anaconda3/envs/tf/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow==2.13.0) (2.13.0)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in /Users/sebastiankotstein/anaconda3/envs/tf/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow==2.13.0) (2.13.0)
# Requirement already satisfied: keras<2.14,>=2.13.1 in /Users/sebastiankotstein/anaconda3/envs/tf/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow==2.13.0) (2.13.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/sebastiankotstein/anaconda3/envs/tf/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow-macos==2.13.0->tensorflow==2.13.0) (0.41.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/sebastiankotstein/anaconda3/envs/tf/lib/python3.9/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (2.23.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /Users/sebastiankotstein/anaconda3/envs/tf/lib/python3.9/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/sebastiankotstein/anaconda3/envs/tf/lib/python3.9/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (3.4.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/sebastiankotstein/anaconda3/envs/tf/lib/python3.9/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/sebastiankotstein/anaconda3/envs/tf/lib/python3.9/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/sebastiankotstein/anaconda3/envs/tf/lib/python3.9/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (2.3.7)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/sebastiankotstein/anaconda3/envs/tf/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/sebastiankotstein/anaconda3/envs/tf/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/sebastiankotstein/anaconda3/envs/tf/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (4.9)
# Requirement already satisfied: urllib3<2.0 in /Users/sebastiankotstein/anaconda3/envs/tf/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (1.26.16)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/sebastiankotstein/anaconda3/envs/tf/lib/python3.9/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/sebastiankotstein/anaconda3/envs/tf/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (6.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/sebastiankotstein/anaconda3/envs/tf/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sebastiankotstein/anaconda3/envs/tf/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sebastiankotstein/anaconda3/envs/tf/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/sebastiankotstein/anaconda3/envs/tf/lib/python3.9/site-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (2.1.3)
# Requirement already satisfied: zipp>=0.5 in /Users/sebastiankotstein/anaconda3/envs/tf/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (3.16.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /Users/sebastiankotstein/anaconda3/envs/tf/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/sebastiankotstein/anaconda3/envs/tf/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (3.2.2)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: transformers==4.33.2 in /Users/sebastiankotstein/anaconda3/envs/tf/lib/python3.9/site-packages (4.33.2)
# Requirement already satisfied: filelock in /Users/sebastiankotstein/anaconda3/envs/tf/lib/python3.9/site-packages (from transformers==4.33.2) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.15.1 in /Users/sebastiankotstein/anaconda3/envs/tf/lib/python3.9/site-packages (from transformers==4.33.2) (0.29.1)
# Requirement already satisfied: numpy>=1.17 in /Users/sebastiankotstein/anaconda3/envs/tf/lib/python3.9/site-packages (from transformers==4.33.2) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /Users/sebastiankotstein/anaconda3/envs/tf/lib/python3.9/site-packages (from transformers==4.33.2) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/sebastiankotstein/anaconda3/envs/tf/lib/python3.9/site-packages (from transformers==4.33.2) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /Users/sebastiankotstein/anaconda3/envs/tf/lib/python3.9/site-packages (from transformers==4.33.2) (2024.11.6)
# Requirement already satisfied: requests in /Users/sebastiankotstein/anaconda3/envs/tf/lib/python3.9/site-packages (from transformers==4.33.2) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /Users/sebastiankotstein/anaconda3/envs/tf/lib/python3.9/site-packages (from transformers==4.33.2) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /Users/sebastiankotstein/anaconda3/envs/tf/lib/python3.9/site-packages (from transformers==4.33.2) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /Users/sebastiankotstein/anaconda3/envs/tf/lib/python3.9/site-packages (from transformers==4.33.2) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/sebastiankotstein/anaconda3/envs/tf/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.15.1->transformers==4.33.2) (2025.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/sebastiankotstein/anaconda3/envs/tf/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.15.1->transformers==4.33.2) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/sebastiankotstein/anaconda3/envs/tf/lib/python3.9/site-packages (from requests->transformers==4.33.2) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sebastiankotstein/anaconda3/envs/tf/lib/python3.9/site-packages (from requests->transformers==4.33.2) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/sebastiankotstein/anaconda3/envs/tf/lib/python3.9/site-packages (from requests->transformers==4.33.2) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sebastiankotstein/anaconda3/envs/tf/lib/python3.9/site-packages (from requests->transformers==4.33.2) (2023.7.22)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: numpy==1.24.3 in /Users/sebastiankotstein/anaconda3/envs/tf/lib/python3.9/site-packages (1.24.3)

# %%
from tools.pipeline.pipeline import Pipeline
from tools.pipeline.lru_cache import LRUCache

import pandas as pd

# %% [markdown]
# ## Arguments
# The following models are available on HuggingFace:
# - Parameter Matching: [SebastianKotstein/restberta-qa-parameter-matching](https://huggingface.co/SebastianKotstein/restberta-qa-parameter-matching)
# - Endpoint Discovery: [SebastianKotstein/restberta-qa-endpoint-discovery](https://huggingface.co/SebastianKotstein/restberta-qa-endpoint-discovery)
# - RESTBERTa model for both tasks: [SebastianKotstein/restberta-qa-pm-ed](https://huggingface.co/SebastianKotstein/restberta-qa-pm-ed)

# %%
# Model name (see description above)
model = "SebastianKotstein/restberta-qa-parameter-matching"

# For a model with an input (context) length of 512 tokens, there are up to to 512x512 possible start-end token pairs, each representing a potential answer span.
# The output interpreter ranks these spans by assigning a score to each start-end pair. This score is computed as the sum of the start and the end logit.
# To improve performance, it is recommended to restrict this computation to only the top 'n' start and end tokens, i.e., those with the highest logits.
# This reduces the number of computations from 512x512 to 20x20, if n = 20, for instance.
best_size = 20

# The pipeline implements an LRU cache that allows us to cache the last 'n' prediction results.
# To disable caching, set this parameter to 'None'.
cache_size = 100

# If 'True', duplicates will be removed from the ranked list of suggested Web API elements so that a suggested Web API element occurs only once with the highest score among all its duplicates.
suppress_duplicates = True

# For each fragment, RESTBERTa outputs a threshold value (also refered as 'NULL answer score') indicating whether the fragment contains the queried Web API element or not. 
# If this parameter is set to 'treshold', only Web API elements with a score higher than the threshold value of the respective fragment will be returned. 
# If set to 'ignore', these threshold values will be ignored.
no_answer_strategy = "ignore"

# If set, only the 'x' highest ranked suggested Web API elements will be contained in the result list.
top_answers_n = None

# Hugging Face access token for loading custom models from private repositories.
token = None

# %% [markdown]
# ## Initialize Pipeline
# The following code initializes the processing pipelines that we also use for the Flask application.
# If a GPU is available for inference, the output should look like the following:<br>
# `[PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]`

# %%
if cache_size:
    cache = LRUCache(cache_size,False)
else:
    cache = None
pipeline = Pipeline(model,best_size,cache,token)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# All model checkpoint layers were used when initializing TFRobertaForQuestionAnswering.
#
# All the layers of TFRobertaForQuestionAnswering were initialized from the model checkpoint at SebastianKotstein/restberta-qa-parameter-matching.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaForQuestionAnswering for predictions without further training.

# %% [markdown]
# ## Pipeline Input
# The pipelines accepts the an dictionary as input having the following structure: <br>
# - On root level, the dictionary has property `schemas`, which is an array. Depending on the task, each `schema` item represents either a payload schema or a list of endpoints.
# - A `schema` item has a `value` property containing the linear list of Web API element in an XPath-like notation. These Web API elements are the properties of the payload schema of the endpoints of the endpoint list.
# - The `queries` array enables the definition of multiple queries per `schema` item. Each query should be expressed in natural language in the `value` property. Assigning a unique identifier to `queryId` is optional but can be helpful for mapping results back to their corresponding queries.
# - Set the `verboseOutput`flag to `True` to obtain details about processed tokens and fragment-level results.
#
# Note that each query is processed independently of the others. <br>
# For more details, we refer to the [OpenAPI](https://github.com/SebastianKotstein/RESTBERTa/blob/master/tools/static/OpenAPI.yml) documentation of the Flask application.

# %%
input = {
    "schemas":[
        {
            "schemaId": "s1",
            "name": "testSchema",
            "value": "auth.key location.city location.city_id location.country location.lat location.lon location.postal_code state units", 
            "queries":[
                {
                    "queryId": "q1",
                    "name": "first query",
                    "value": "The ZIP",
                    "verboseOutput":False
                },
                {
                    "queryId": "q2",
                    "name": "second query",
                    "value": "The auth token",
                    "verboseOutput":False
                }

            ]
        }
    ]
}

results = pipeline.process(input,top_answers_n,suppress_duplicates,no_answer_strategy)

# %% [markdown]
# ## Output Visualization

# %%
def display_results(results, sort_by = None):
    pd.set_option('display.max_rows', None)
    df = pd.DataFrame(results)
    if sort_by:
        df = df.sort_values(sort_by, ascending=False)
    df = df.style.set_properties(**{'text-align': 'left'})
    display(df)

# %%
query_tables = {}  # Store DataFrames per queryId

for schema in results['schemas']:
    schema_name = schema['name']
    for query in schema['queries']:
        query_name = query['name']
        answers = query['result'].get('answers', [])
        
        # Build DataFrame
        df = pd.DataFrame([
            {'Property': ans['property']['name'], 'Score': float(ans['score'])}
            for ans in answers
            if ans['property'] is not None
        ])
        
        print(f"\nSchema: {schema_name} | Query: {query_name}")
        display_results(df)
# Out:
# Schema: testSchema | Query: first query
# <style type="text/css">
# #T_332fb_row0_col0, #T_332fb_row0_col1, #T_332fb_row1_col0, #T_332fb_row1_col1, #T_332fb_row2_col0, #T_332fb_row2_col1, #T_332fb_row3_col0, #T_332fb_row3_col1, #T_332fb_row4_col0, #T_332fb_row4_col1, #T_332fb_row5_col0, #T_332fb_row5_col1, #T_332fb_row6_col0, #T_332fb_row6_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_332fb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_332fb_level0_col0" class="col_heading level0 col0" >Property</th>
#       <th id="T_332fb_level0_col1" class="col_heading level0 col1" >Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_332fb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_332fb_row0_col0" class="data row0 col0" >location.postal_code</td>
#       <td id="T_332fb_row0_col1" class="data row0 col1" >16.057260</td>
#     </tr>
#     <tr>
#       <th id="T_332fb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_332fb_row1_col0" class="data row1 col0" >location.lon</td>
#       <td id="T_332fb_row1_col1" class="data row1 col1" >1.122429</td>
#     </tr>
#     <tr>
#       <th id="T_332fb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_332fb_row2_col0" class="data row2 col0" >location.city_id</td>
#       <td id="T_332fb_row2_col1" class="data row2 col1" >-6.211535</td>
#     </tr>
#     <tr>
#       <th id="T_332fb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_332fb_row3_col0" class="data row3 col0" >location.city</td>
#       <td id="T_332fb_row3_col1" class="data row3 col1" >-6.740502</td>
#     </tr>
#     <tr>
#       <th id="T_332fb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_332fb_row4_col0" class="data row4 col0" >location.country</td>
#       <td id="T_332fb_row4_col1" class="data row4 col1" >-8.156937</td>
#     </tr>
#     <tr>
#       <th id="T_332fb_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_332fb_row5_col0" class="data row5 col0" >auth.key</td>
#       <td id="T_332fb_row5_col1" class="data row5 col1" >-9.358548</td>
#     </tr>
#     <tr>
#       <th id="T_332fb_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_332fb_row6_col0" class="data row6 col0" >location.lat</td>
#       <td id="T_332fb_row6_col1" class="data row6 col1" >-11.109827</td>
#     </tr>
#   </tbody>
# </table>
# Schema: testSchema | Query: second query
# <style type="text/css">
# #T_0e828_row0_col0, #T_0e828_row0_col1, #T_0e828_row1_col0, #T_0e828_row1_col1, #T_0e828_row2_col0, #T_0e828_row2_col1, #T_0e828_row3_col0, #T_0e828_row3_col1, #T_0e828_row4_col0, #T_0e828_row4_col1, #T_0e828_row5_col0, #T_0e828_row5_col1, #T_0e828_row6_col0, #T_0e828_row6_col1, #T_0e828_row7_col0, #T_0e828_row7_col1, #T_0e828_row8_col0, #T_0e828_row8_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_0e828">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0e828_level0_col0" class="col_heading level0 col0" >Property</th>
#       <th id="T_0e828_level0_col1" class="col_heading level0 col1" >Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0e828_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0e828_row0_col0" class="data row0 col0" >auth.key</td>
#       <td id="T_0e828_row0_col1" class="data row0 col1" >17.928198</td>
#     </tr>
#     <tr>
#       <th id="T_0e828_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0e828_row1_col0" class="data row1 col0" >location.city</td>
#       <td id="T_0e828_row1_col1" class="data row1 col1" >-11.495063</td>
#     </tr>
#     <tr>
#       <th id="T_0e828_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0e828_row2_col0" class="data row2 col0" >location.city_id</td>
#       <td id="T_0e828_row2_col1" class="data row2 col1" >-19.220545</td>
#     </tr>
#     <tr>
#       <th id="T_0e828_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0e828_row3_col0" class="data row3 col0" >location.postal_code</td>
#       <td id="T_0e828_row3_col1" class="data row3 col1" >-19.519812</td>
#     </tr>
#     <tr>
#       <th id="T_0e828_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0e828_row4_col0" class="data row4 col0" >location.lon</td>
#       <td id="T_0e828_row4_col1" class="data row4 col1" >-19.534370</td>
#     </tr>
#     <tr>
#       <th id="T_0e828_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0e828_row5_col0" class="data row5 col0" >location.country</td>
#       <td id="T_0e828_row5_col1" class="data row5 col1" >-19.603506</td>
#     </tr>
#     <tr>
#       <th id="T_0e828_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0e828_row6_col0" class="data row6 col0" >location.lat</td>
#       <td id="T_0e828_row6_col1" class="data row6 col1" >-19.605970</td>
#     </tr>
#     <tr>
#       <th id="T_0e828_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0e828_row7_col0" class="data row7 col0" >state</td>
#       <td id="T_0e828_row7_col1" class="data row7 col1" >-19.802938</td>
#     </tr>
#     <tr>
#       <th id="T_0e828_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0e828_row8_col0" class="data row8 col0" >units</td>
#       <td id="T_0e828_row8_col1" class="data row8 col1" >-19.832052</td>
#     </tr>
#   </tbody>
# </table>
